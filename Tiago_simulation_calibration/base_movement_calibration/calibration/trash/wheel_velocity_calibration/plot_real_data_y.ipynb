# %%
from plot_real_data import plot_real_data
# Directory containing the processed data folders
input_directory = "../../trajectory_data/real/y"

plot_real_data(input_directory)

# %% [markdown]
# Comparing these Avg Vel values with the simulator Articulation Controller's values,  we can see that we have an about 0.5 % error only.
