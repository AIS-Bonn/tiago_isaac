# %%
from utils import plot_trajectory_stats

# Define the directories containing the real and simulation data
real_dir = '../trajectory_data/real/recordings/r_sidewards/poses'
simulation_dir = '../trajectory_data/simulation/recordings/r_sidewards/1000/poses'
simulation_light_dir = '../trajectory_data/simulation/recordings_light_simulation/r_sidewards/60/poses'


plot_trajectory_stats(real_dir, simulation_dir, simulation_light_dir)
# Out:
# No corresponding simulation files found for real files with params (0.0, 0.015708, 0.15708, 4.0, False)
# No corresponding simulation files found for real files with params (0.0, 0.015708, 0.314159, 4.0, False)
# /home/vinci/anaconda3/envs/RL_env/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /home/vinci/anaconda3/envs/RL_env/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:715: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# No corresponding simulation files found for real files with params (0.0, 0.0314159, 0.15708, 4.0, False)
# No corresponding simulation files found for real files with params (0.0, 0.0314159, 0.314159, 4.0, False)
# No corresponding simulation files found for real files with params (0.0, 0.0314159, 0.628319, 4.0, False)
# ...
