# %%
from utils import plot_trajectory_stats

# Define the directories containing the real and simulation data
real_dir = '../trajectory_data/real/recordings/forward_circle/poses'
simulation_dir = '../trajectory_data/simulation/recordings/forward_circle/1000/poses'
simulation_light_dir = '../trajectory_data/simulation/recordings_light_simulation/forward_circle/60/poses'


plot_trajectory_stats(real_dir, simulation_dir, simulation_light_dir)
# Out:
# /home/vinci/anaconda3/envs/optim/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /home/vinci/anaconda3/envs/optim/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:715: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /home/vinci/anaconda3/envs/optim/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /home/vinci/anaconda3/envs/optim/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:715: RuntimeWarning: invalid value encountered in multiply
#   y_new = slope*(x_new - x_lo)[:, None] + y_lo
# /home/vinci/anaconda3/envs/optim/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: divide by zero encountered in divide
# ...
