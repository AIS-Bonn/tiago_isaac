# %%
from utils import plot_trajectory_stats

# Define the directories containing the real and simulation data
real_dir = '../trajectory_data/real/recordings/r_forwards/poses'
simulation_dir = '../trajectory_data/simulation/recordings/r_forwards/1000/poses'
simulation_light_dir = '../trajectory_data/simulation/recordings_light_simulation/r_forwards/60/poses'


plot_trajectory_stats(real_dir, simulation_dir, simulation_light_dir)
# Out:
# No corresponding simulation files found for real files with params (0.015708, 0.0, 0.15708, 4.0, False)
# No corresponding simulation files found for real files with params (0.015708, 0.0, 0.314159, 4.0, False)
# No corresponding simulation files found for real files with params (0.0314159, 0.0, 0.15708, 4.0, False)
# No corresponding simulation files found for real files with params (0.0314159, 0.0, 0.314159, 4.0, False)
# No corresponding simulation files found for real files with params (0.0314159, 0.0, 0.628319, 4.0, False)
# No corresponding simulation files found for real files with params (0.0471239, 0.0, 0.15708, 4.0, False)
# No corresponding simulation files found for real files with params (0.0471239, 0.0, 0.314159, 4.0, False)
# No corresponding simulation files found for real files with params (0.0471239, 0.0, 0.471239, 4.0, False)
# No corresponding simulation files found for real files with params (0.0628319, 0.0, 0.314159, 4.0, False)
# ...
